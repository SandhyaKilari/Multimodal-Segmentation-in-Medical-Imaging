# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Model
from keras.layers import Input, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, Dropout
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from sklearn.model_selection import train_test_split

# Set your data directory
data_dir = '/kaggle/input/trainx/train/train'  # Change this to your dataset path
image_dir = os.path.join(data_dir, "images")
mask_dir = os.path.join(data_dir, "masks")

# List files
image_names = sorted(os.listdir(image_dir))
mask_names = sorted(os.listdir(mask_dir))

common_files = set(image_names) & set(mask_names)
image_names = sorted([name for name in image_names if name in common_files])
mask_names = sorted([name for name in mask_names if name in common_files])

# Make sure that image_names and mask_names correspond one-to-one
assert len(image_names) == len(mask_names), "Number of images and masks do not match."

# Desired shapes
input_image_shape = (256, 256)  # Input size
mask_shape = (256, 256)         # Output mask

X = []
Y = []

for img_name, msk_name in zip(image_names, mask_names):
    img_path = os.path.join(image_dir, img_name)
    msk_path = os.path.join(mask_dir, msk_name)

    # Read images in grayscale
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    msk = cv2.imread(msk_path, cv2.IMREAD_GRAYSCALE)

    # Resize to desired shapes
    img = cv2.resize(img, input_image_shape)
    msk = cv2.resize(msk, mask_shape)

    # Normalize (if you want to normalize)
    img = img.astype(np.float32) / 255.0
    msk = msk.astype(np.float32) / 255.0

    # Add channel dimension
    img = np.expand_dims(img, axis=-1)  # (256,256,1)
    msk = np.expand_dims(msk, axis=-1)  # (256,256,1)

    X.append(img)
    Y.append(msk)

X = np.array(X)
Y = np.array(Y)

print('Dataset shape :', X.shape, Y.shape)  # X: (N,256,256,1), Y: (N,256,256,1)

# Split dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print(f"Training set shape: {X_train.shape}, {Y_train.shape}")
print(f"Testing set shape: {X_test.shape}, {Y_test.shape}")

# Create HQ-SAM-inspired model
def create_hq_sam(input_shape=(256, 256, 1)):
    inputs = Input(input_shape)

    # Encoder
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    # Bottleneck
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(c4)
    d4 = Dropout(0.5)(c4)

    # Decoder
    u5 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(d4)
    u5 = concatenate([u5, c3])
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same')(u5)
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same')(c5)

    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c2])
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(u6)
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c1])
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(u7)
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(c7)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c7)

    model = Model(inputs, outputs)
    return model

# Create and compile the model
model = create_hq_sam()
model.compile(optimizer=Adam(learning_rate=1e-4), loss=BinaryCrossentropy(), metrics=['accuracy'])

print('Model Summary:')
model.summary()

# Train the model
epochs = 20
batch_size = 16

history = model.fit(
    X_train, Y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2
)

# Evaluate on the test set
test_loss, test_accuracy = model.evaluate(X_test, Y_test, batch_size=batch_size)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# Save the final model
model.save("hq_sam_final.weights.h5")

# Plot training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss', linestyle='--')
plt.title("Learning Curve")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# Visualize a sample
y_pred = model.predict(X_test)

# Choose a sample index
idx = np.random.randint(0, len(X_test))
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

# Input Image
ax[0].imshow(X_test[idx].reshape(256, 256), cmap='gray')
ax[0].set_title('Input Image')
ax[0].axis('off')

# Ground Truth Mask
ax[1].imshow(Y_test[idx].reshape(256, 256), cmap='gray')
ax[1].set_title('Ground Truth Mask')
ax[1].axis('off')

# Predicted Mask
ax[2].imshow(y_pred[idx].reshape(256, 256), cmap='gray')
ax[2].set_title('Predicted Mask')
ax[2].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Dataset shape : (1717, 256, 256, 1) (1717, 256, 256, 1)
# Training set shape: (1373, 256, 256, 1), (1373, 256, 256, 1)
# Testing set shape: (344, 256, 256, 1), (344, 256, 256, 1)
# Model Summary:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 256, 256,  │        640 │ input_layer_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 256, 256,  │     36,928 │ conv2d_30[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 128, 128,  │          0 │ conv2d_31[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 128, 128,  │     73,856 │ max_pooling2d_6[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 128, 128,  │    147,584 │ conv2d_32[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 64, 64,    │          0 │ conv2d_33[0][0]   │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 64, 64,    │    295,168 │ max_pooling2d_7[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 64, 64,    │    590,080 │ conv2d_34[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 32, 32,    │          0 │ conv2d_35[0][0]   │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 32, 32,    │  1,180,160 │ max_pooling2d_8[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 32, 32,    │  2,359,808 │ conv2d_36[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_37[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_6  │ (None, 64, 64,    │    524,544 │ dropout_2[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ conv2d_35[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 64, 64,    │  1,179,904 │ concatenate_6[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 64, 64,    │    590,080 │ conv2d_38[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (None, 128, 128,  │    131,200 │ conv2d_39[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_33[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 128, 128,  │    295,040 │ concatenate_7[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 128, 128,  │    147,584 │ conv2d_40[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_8  │ (None, 256, 256,  │     32,832 │ conv2d_41[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_31[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 256, 256,  │     73,792 │ concatenate_8[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 256, 256,  │     36,928 │ conv2d_42[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 256, 256,  │         65 │ conv2d_43[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,696,193 (29.36 MB)
#  Trainable params: 7,696,193 (29.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 49s 618ms/step - accuracy: 0.8429 - loss: 0.5514 - val_accuracy: 0.8437 - val_loss: 0.4115
# Epoch 2/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 280ms/step - accuracy: 0.8409 - loss: 0.3958 - val_accuracy: 0.8437 - val_loss: 0.3314
# Epoch 3/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 281ms/step - accuracy: 0.8427 - loss: 0.3199 - val_accuracy: 0.8455 - val_loss: 0.2735
# Epoch 4/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 281ms/step - accuracy: 0.8584 - loss: 0.2769 - val_accuracy: 0.8910 - val_loss: 0.2322
# Epoch 5/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 281ms/step - accuracy: 0.8956 - loss: 0.2238 - val_accuracy: 0.9235 - val_loss: 0.1777
# Epoch 6/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 281ms/step - accuracy: 0.9213 - loss: 0.1822 - val_accuracy: 0.9388 - val_loss: 0.1462
# Epoch 7/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 281ms/step - accuracy: 0.9383 - loss: 0.1465 - val_accuracy: 0.9461 - val_loss: 0.1282
# Epoch 8/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 281ms/step - accuracy: 0.9466 - loss: 0.1255 - val_accuracy: 0.9547 - val_loss: 0.1096
# Epoch 9/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 281ms/step - accuracy: 0.9543 - loss: 0.1085 - val_accuracy: 0.9574 - val_loss: 0.1001
# Epoch 10/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 281ms/step - accuracy: 0.9598 - loss: 0.0953 - val_accuracy: 0.9599 - val_loss: 0.0989
# Epoch 11/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 281ms/step - accuracy: 0.9637 - loss: 0.0869 - val_accuracy: 0.9674 - val_loss: 0.0782
# Epoch 12/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 281ms/step - accuracy: 0.9665 - loss: 0.0796 - val_accuracy: 0.9685 - val_loss: 0.0749
# Epoch 13/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 281ms/step - accuracy: 0.9688 - loss: 0.0734 - val_accuracy: 0.9696 - val_loss: 0.0705
# Epoch 14/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 282ms/step - accuracy: 0.9705 - loss: 0.0689 - val_accuracy: 0.9730 - val_loss: 0.0629
# Epoch 15/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 282ms/step - accuracy: 0.9727 - loss: 0.0644 - val_accuracy: 0.9759 - val_loss: 0.0556
# Epoch 16/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 281ms/step - accuracy: 0.9731 - loss: 0.0625 - val_accuracy: 0.9763 - val_loss: 0.0551
# Epoch 17/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 281ms/step - accuracy: 0.9747 - loss: 0.0586 - val_accuracy: 0.9752 - val_loss: 0.0584
# Epoch 18/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 281ms/step - accuracy: 0.9734 - loss: 0.0611 - val_accuracy: 0.9781 - val_loss: 0.0500
# Epoch 19/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 282ms/step - accuracy: 0.9774 - loss: 0.0517 - val_accuracy: 0.9783 - val_loss: 0.0490
# Epoch 20/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 19s 282ms/step - accuracy: 0.9775 - loss: 0.0512 - val_accuracy: 0.9781 - val_loss: 0.0493
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - accuracy: 0.9786 - loss: 0.0482
# Test Accuracy: 97.79%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step
